# %% [markdown]
# #Title: Tools for Data Science

# %% [markdown]
# This notebook provides an overview of key Data Science languages, libraries, and tools.

# %% [markdown]
# Here are some of the popular programming languages used in Data Science:
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Julia

# %% [markdown]
# The following are some commonly used Data Science libraries:
# 1. Pandas
# 2. NumPy
# 3. Scikit-Learn
# 4. TensorFlow
# 5. Matplotlib

# %% [markdown]
# | Data Science Tool     | Description                         |
# |-----------------------|-------------------------------------|
# | Jupyter Notebook      | Interactive computing environment   |
# | RStudio               | IDE for R programming               |
# | Apache Hadoop         | Distributed data processing framework |

# %% [markdown]
# ###The following section shows examples of arithmetic expressions in Python.

# %%
# This code multiplies and adds two numbers
result = (5 * 6) + 3
result
# Out:
# 33

# %%
# This code converts 120 minutes to hours
hours = 120 / 60
hours
# Out:
# 2.0

# %% [markdown]
# The objectives of this project are:
# - Understand basic data science tools and techniques
# - Learn how to visualize data
# - Get familiar with popular programming languages used in data science

# %% [markdown]
# **Author**: Gwyn Lobaton
